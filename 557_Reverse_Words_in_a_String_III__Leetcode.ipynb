# %% [markdown]
# <a href="https://colab.research.google.com/github/yakovsushenok/Algorithms-and-Data-Structures/blob/main/557_Reverse_Words_in_a_String_III__Leetcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given a string `s`, reverse the order of characters in each word within a sentence while still preserving whitespace and initial word order.
#
#
#
# ## Example 1:
#
# ```
# Input: s = "Let's take LeetCode contest"
# Output: "s'teL ekat edoCteeL tsetnoc"
# ```
#
# ## Example 2:
#
# ```
# Input: s = "God Ding"
# Output: "doG gniD"
# ```
#
# ## Constraints:
#
# ```
# 1 <= s.length <= 5 * 104
# s contains printable ASCII characters.
# s does not contain any leading or trailing spaces.
# There is at least one word in s.
# All the words in s are separated by a single space.
# ```

# %% [markdown]
# # Solution: Todo (explanation) --> bad solution

# %%
def reverseWords(s):
        """
        :type s: str
        :rtype: str
        """
        spaces = [-1]
        for i in range(len(s)):
            if s[i] == " ":
                spaces.append(i)
        spaces.append(-1)
        # now I'll slice the array into word and reverse them in-place
        s1 = []
        for i in range(len(spaces)-1):
            if i == len(spaces) - 2:
                s1.append(''.join(list(reversed((list(s[spaces[i]+1:]))))))
            else:
                s1.append(''.join(list(reversed((list(s[spaces[i]+1:spaces[i+1]]))))))
        return ' '.join(s1)
